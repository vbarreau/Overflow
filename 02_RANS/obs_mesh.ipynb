# %%
import sys
import tkinter as tk
from tkinter import ttk
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
sys.path.append(r"D:/OneDrive/Documents/11-Codes/overflow/02_RANS")
from geom import *

# %%
circle_mesh = Mesh(filename = r'D:\OneDrive\Documents\11-Codes\overflow\02_RANS\circle_mesh.dat')
# Out:
# Lecture du maillage: 100%|██████████| 12808/12808 [00:00<00:00, 158695.96it/s]

# %%
fig, ax = plt.subplots(figsize=(15, 8))
circle_mesh.plot_mesh(ax=ax)
ax.set_xlim(-0.1,20)
ax.set_aspect('equal')
plt.plot()
# Out:
# Plotting...: 100%|██████████| 6404/6404 [00:03<00:00, 1924.19it/s]
# []

# %%
circle_mesh.plot_distance_to_wall_heatmap()
plt.show()
# Out:
# 100%|██████████| 3132/3132 [00:00<00:00, 3070724.67it/s]
